# %%
import pandas as pd
import numpy as np  
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import spearmanr

# %%
# Information about individual channels/hotels
data_lake_prd_314410_cz_canais = pd.read_csv('../data/lookups/data-lake-prd-314410.cz.canais.csv')
data_lake_prd_314410_cz_hoteis = pd.read_csv('../data/lookups/data-lake-prd-314410.cz.hoteis.csv')
data_lake_prd_314410_cz_cidades = pd.read_csv('../data/lookups/data-lake-prd-314410.cz.cidades.csv')

# List of hotel-channel combinations as of January 2025
hotel_city_chanel_combin_extract  = pd.read_csv('../data/other/hotel_city_chanel_combin_extract.csv')
hotel_city_chanel_combin_extract.dropna(inplace=True)
hotel_city_chanel_combin_extract.drop(columns=['Cidade_ID'], inplace=True)
hotel_city_chanel_combin_extract.drop_duplicates(inplace=True)

unique_hotels_lookupID = data_lake_prd_314410_cz_hoteis['Hotel_ID'].unique()
unique_chanels_lookupID = data_lake_prd_314410_cz_canais['Canal_ID'].unique()

# %%
hotel_city_chanel_combin_extract = hotel_city_chanel_combin_extract.merge(
    data_lake_prd_314410_cz_hoteis[['Hotel_ID', 'StatusHotel']],
    on='Hotel_ID',
    how='left'
)

hotel_city_chanel_combin_extract = hotel_city_chanel_combin_extract[ 
    (hotel_city_chanel_combin_extract['StatusHotel'] == '3. Ativo') | 
    (hotel_city_chanel_combin_extract['StatusHotel'] == '4. Inativo')]

hotel_city_chanel_combin_extract = hotel_city_chanel_combin_extract.drop(columns=['StatusHotel'])

hotel_city_chanel_combin_extract['Canal_ID'] = hotel_city_chanel_combin_extract['Canal_ID'].astype('int64')
hotel_city_chanel_combin_extract['Hotel_ID'] = hotel_city_chanel_combin_extract['Hotel_ID'].astype('int64')

hotel_city_chanel_combin_extract = hotel_city_chanel_combin_extract[
    hotel_city_chanel_combin_extract['Hotel_ID'].isin(unique_hotels_lookupID)
]

hotel_city_chanel_combin_extract = hotel_city_chanel_combin_extract[
    hotel_city_chanel_combin_extract['Canal_ID'].isin(unique_chanels_lookupID)
]

# %%
# Pivot the table
pivot_table = hotel_city_chanel_combin_extract.pivot_table(index='Hotel_ID', columns='Canal_ID', aggfunc='size', fill_value=0)

# Convert the table to binary (1 where the combination existed, 0 otherwise)
pivot_table = pivot_table.map(lambda x: 1 if x > 0 else 0)

# %%
def compute_channel_scores_excluding_existing(pivot_table):
    """
    Compute recommendation scores for each hotel and channel, excluding channels already used.
    
    Parameters:
    - pivot_table: DataFrame with Hotel_ID as rows, Canal_ID as columns (0/1 values).
    
    Returns:
    - scores_df: DataFrame with the same shape, containing recommendation scores,
                 but zeros where the hotel already used the channel.
    """

    # Step 1: Compute cosine similarity between hotels (rows)
    similarity_matrix = cosine_similarity(pivot_table.values)
    np.fill_diagonal(similarity_matrix, 0)  # remove self-similarity

    # Step 2: Multiply similarity matrix with original matrix to get weighted channel usage
    weighted_scores = np.dot(similarity_matrix, pivot_table.values)

    # Step 3: Create a DataFrame with these scores
    scores_df = pd.DataFrame(weighted_scores, index=pivot_table.index, columns=pivot_table.columns)

    # Step 4: Remove already-used channels (mask with 0 where pivot_table == 1)
    scores_df[pivot_table == 1] = 0

    return scores_df

# %%
scores_df = compute_channel_scores_excluding_existing(pivot_table)

# %%
# Get top 10 recommended channels for a specific hotel
hotel_id = 7
top_channels = scores_df.loc[hotel_id].sort_values(ascending=False).head(10)
print(top_channels)
# Out:
# Canal_ID
# 124     64.769288
# 104     62.926124
# 908     61.474724
# 608     60.865617
# 607     60.536693
# 1195    60.509170
# 1145    60.116195
# 1168    59.174268
# 833     58.032550
# 810     56.638884
# Name: 7, dtype: float64

# %%
# Convert wide format to long format
long_scores_df = scores_df.stack().reset_index()

# Rename columns
long_scores_df.columns = ['hotel_id', 'channel_id', 'score']

# Drop zero scores
long_scores_df = long_scores_df[long_scores_df['score'] > 0].reset_index(drop=True)

# %%
def get_top_channels_for_hotel(hotel_id, scores_df, top_n=500):
    # Get non-zero scores sorted descending
    hotel_scores = scores_df.loc[hotel_id]
    top_channels = hotel_scores[hotel_scores > 0].sort_values(ascending=False).head(top_n)
    return set(top_channels.index)


def compare_channel_overlap(hotel_id, similarity_df, scores_df, top_similar=1000, top_channels=500):
    # Get top N similar hotels excluding self
    similar_hotels = (
        similarity_df.loc[hotel_id]
        .drop(hotel_id)
        .sort_values(ascending=False)
        .head(top_similar)
        .index
        .tolist()
    )
    
    # Get the chosen hotel’s top channels
    hotel_channels = get_top_channels_for_hotel(hotel_id, scores_df, top_channels)
    
    overlaps = {}
    for sim_hotel in similar_hotels:
        sim_channels = get_top_channels_for_hotel(sim_hotel, scores_df, top_channels)
        intersection_size = len(hotel_channels.intersection(sim_channels))
        overlaps[sim_hotel] = intersection_size
    
    return overlaps

# %%
similarity_matrix = cosine_similarity(pivot_table)
np.fill_diagonal(similarity_matrix, 0) 
similarity_df = pd.DataFrame(similarity_matrix, index=pivot_table.index, columns=pivot_table.index)

# %%
hotel_id = 7

overlaps = compare_channel_overlap(hotel_id, similarity_df, scores_df)

print(f"Channel overlap (top 100) between hotel {hotel_id} and each of its top 10 similar hotels:")

for sim_hotel, overlap_count in overlaps.items():
    print(f"Hotel {sim_hotel}: {overlap_count} overlapping channels")
# Out:
# Channel overlap (top 100) between hotel 7 and each of its top 10 similar hotels:
# Hotel 1757: 500 overlapping channels
# Hotel 6765: 500 overlapping channels
# Hotel 2758: 500 overlapping channels
# Hotel 1377: 500 overlapping channels
# Hotel 15477: 500 overlapping channels
# Hotel 563: 500 overlapping channels
# Hotel 2296: 500 overlapping channels
# Hotel 531: 500 overlapping channels
# Hotel 4558: 500 overlapping channels
# Hotel 19801: 500 overlapping channels
# Hotel 3592: 500 overlapping channels
# Hotel 6427: 500 overlapping channels
# Hotel 1784: 500 overlapping channels
# Hotel 967: 500 overlapping channels
# Hotel 17205: 500 overlapping channels
# Hotel 8806: 500 overlapping channels
# Hotel 77: 500 overlapping channels
# Hotel 75: 500 overlapping channels
# Hotel 19387: 500 overlapping channels
# Hotel 1649: 500 overlapping channels
# Hotel 1643: 500 overlapping channels
# Hotel 758: 500 overlapping channels
# Hotel 5482: 500 overlapping channels
# Hotel 18299: 500 overlapping channels
# Hotel 11334: 500 overlapping channels
# Hotel 1612: 500 overlapping channels
# Hotel 17106: 500 overlapping channels
# Hotel 23: 500 overlapping channels
# Hotel 645: 500 overlapping channels
# Hotel 17: 500 overlapping channels
# Hotel 19532: 500 overlapping channels
# Hotel 164: 500 overlapping channels
# Hotel 4827: 494 overlapping channels
# Hotel 10897: 495 overlapping channels
# Hotel 13002: 495 overlapping channels
# Hotel 20458: 495 overlapping channels
# Hotel 12701: 496 overlapping channels
# Hotel 14979: 493 overlapping channels
# Hotel 5381: 495 overlapping channels
# Hotel 5607: 495 overlapping channels
# Hotel 15334: 490 overlapping channels
# Hotel 931: 493 overlapping channels
# Hotel 16234: 493 overlapping channels
# Hotel 20723: 493 overlapping channels
# Hotel 20675: 492 overlapping channels
# Hotel 9851: 493 overlapping channels
# Hotel 9834: 494 overlapping channels
# Hotel 15923: 492 overlapping channels
# Hotel 6415: 492 overlapping channels
# Hotel 6827: 494 overlapping channels
# Hotel 5351: 492 overlapping channels
# Hotel 9784: 494 overlapping channels
# Hotel 9969: 492 overlapping channels
# Hotel 9087: 491 overlapping channels
# Hotel 10462: 492 overlapping channels
# Hotel 15011: 488 overlapping channels
# Hotel 16459: 491 overlapping channels
# Hotel 9814: 494 overlapping channels
# Hotel 20185: 494 overlapping channels
# Hotel 10254: 492 overlapping channels
# Hotel 12258: 491 overlapping channels
# Hotel 1793: 490 overlapping channels
# Hotel 20363: 492 overlapping channels
# Hotel 10929: 490 overlapping channels
# Hotel 10469: 491 overlapping channels
# Hotel 14925: 493 overlapping channels
# Hotel 17135: 491 overlapping channels
# Hotel 6973: 490 overlapping channels
# Hotel 7653: 490 overlapping channels
# Hotel 11142: 492 overlapping channels
# Hotel 20603: 491 overlapping channels
# Hotel 6851: 491 overlapping channels
# Hotel 20813: 492 overlapping channels
# Hotel 7502: 490 overlapping channels
# Hotel 16636: 491 overlapping channels
# Hotel 6522: 490 overlapping channels
# Hotel 10745: 491 overlapping channels
# Hotel 17390: 492 overlapping channels
# Hotel 10998: 487 overlapping channels
# Hotel 17204: 488 overlapping channels
# Hotel 9202: 489 overlapping channels
# Hotel 9934: 491 overlapping channels
# Hotel 20645: 475 overlapping channels
# Hotel 17227: 493 overlapping channels
# Hotel 9737: 489 overlapping channels
# Hotel 6786: 487 overlapping channels
# Hotel 19742: 489 overlapping channels
# Hotel 11645: 490 overlapping channels
# Hotel 9739: 489 overlapping channels
# Hotel 8764: 487 overlapping channels
# Hotel 20561: 489 overlapping channels
# Hotel 3777: 490 overlapping channels
# Hotel 14461: 488 overlapping channels
# Hotel 7549: 489 overlapping channels
# Hotel 7235: 489 overlapping channels
# Hotel 9179: 489 overlapping channels
# Hotel 7116: 490 overlapping channels
# Hotel 2430: 489 overlapping channels
# Hotel 20138: 491 overlapping channels
# Hotel 10532: 490 overlapping channels
# Hotel 5027: 490 overlapping channels
# Hotel 14324: 490 overlapping channels
# Hotel 13101: 489 overlapping channels
# Hotel 18018: 489 overlapping channels
# Hotel 14656: 487 overlapping channels
# Hotel 9708: 488 overlapping channels
# Hotel 15468: 487 overlapping channels
# Hotel 20687: 490 overlapping channels
# Hotel 14186: 489 overlapping channels
# Hotel 4208: 490 overlapping channels
# Hotel 6683: 489 overlapping channels
# Hotel 13323: 488 overlapping channels
# Hotel 6060: 490 overlapping channels
# Hotel 8934: 489 overlapping channels
# Hotel 13167: 487 overlapping channels
# Hotel 2390: 488 overlapping channels
# Hotel 6304: 489 overlapping channels
# Hotel 4727: 489 overlapping channels
# Hotel 7949: 490 overlapping channels
# Hotel 3858: 489 overlapping channels
# Hotel 9019: 486 overlapping channels
# Hotel 8633: 489 overlapping channels
# Hotel 14439: 489 overlapping channels
# Hotel 5890: 489 overlapping channels
# Hotel 7051: 487 overlapping channels
# Hotel 8295: 488 overlapping channels
# Hotel 6410: 490 overlapping channels
# Hotel 20489: 490 overlapping channels
# Hotel 20301: 488 overlapping channels
# Hotel 12780: 489 overlapping channels
# Hotel 18336: 490 overlapping channels
# Hotel 7651: 485 overlapping channels
# Hotel 13173: 488 overlapping channels
# Hotel 13192: 489 overlapping channels
# Hotel 7746: 489 overlapping channels
# Hotel 13210: 485 overlapping channels
# Hotel 7372: 489 overlapping channels
# Hotel 12242: 488 overlapping channels
# Hotel 8372: 489 overlapping channels
# Hotel 6396: 489 overlapping channels
# Hotel 5328: 489 overlapping channels
# Hotel 17231: 486 overlapping channels
# Hotel 13496: 490 overlapping channels
# Hotel 5093: 488 overlapping channels
# Hotel 11632: 488 overlapping channels
# Hotel 11554: 488 overlapping channels
# Hotel 6392: 488 overlapping channels
# Hotel 17108: 487 overlapping channels
# Hotel 14310: 487 overlapping channels
# Hotel 6600: 488 overlapping channels
# Hotel 15433: 487 overlapping channels
# Hotel 15568: 487 overlapping channels
# Hotel 8310: 487 overlapping channels
# Hotel 8990: 488 overlapping channels
# Hotel 18014: 487 overlapping channels
# Hotel 7720: 487 overlapping channels
# Hotel 4725: 488 overlapping channels
# Hotel 6223: 487 overlapping channels
# Hotel 7564: 488 overlapping channels
# Hotel 7164: 488 overlapping channels
# Hotel 8719: 489 overlapping channels
# Hotel 8268: 488 overlapping channels
# Hotel 17483: 488 overlapping channels
# Hotel 8: 489 overlapping channels
# Hotel 10252: 489 overlapping channels
# Hotel 10997: 486 overlapping channels
# Hotel 15: 490 overlapping channels
# Hotel 14087: 489 overlapping channels
# Hotel 20276: 489 overlapping channels
# Hotel 4972: 489 overlapping channels
# Hotel 9990: 487 overlapping channels
# Hotel 13920: 483 overlapping channels
# Hotel 20371: 489 overlapping channels
# Hotel 9100: 485 overlapping channels
# Hotel 19852: 488 overlapping channels
# Hotel 19732: 488 overlapping channels
# Hotel 11655: 488 overlapping channels
# Hotel 11656: 487 overlapping channels
# Hotel 9916: 486 overlapping channels
# Hotel 8600: 484 overlapping channels
# Hotel 19754: 488 overlapping channels
# Hotel 20206: 487 overlapping channels
# Hotel 5729: 486 overlapping channels
# Hotel 13866: 487 overlapping channels
# Hotel 4531: 488 overlapping channels
# Hotel 18187: 487 overlapping channels
# Hotel 16684: 487 overlapping channels
# Hotel 19081: 490 overlapping channels
# Hotel 11015: 485 overlapping channels
# Hotel 11210: 489 overlapping channels
# Hotel 8323: 488 overlapping channels
# Hotel 13392: 487 overlapping channels
# Hotel 20658: 489 overlapping channels
# Hotel 14441: 487 overlapping channels
# Hotel 14150: 486 overlapping channels
# Hotel 3919: 486 overlapping channels
# Hotel 10226: 489 overlapping channels
# Hotel 7626: 487 overlapping channels
# Hotel 9604: 487 overlapping channels
# Hotel 9544: 487 overlapping channels
# Hotel 3645: 488 overlapping channels
# Hotel 4562: 483 overlapping channels
# Hotel 2136: 482 overlapping channels
# Hotel 10020: 482 overlapping channels
# Hotel 13749: 487 overlapping channels
# Hotel 18426: 487 overlapping channels
# Hotel 16682: 489 overlapping channels
# Hotel 20082: 485 overlapping channels
# Hotel 6623: 485 overlapping channels
# Hotel 12496: 486 overlapping channels
# Hotel 7275: 486 overlapping channels
# Hotel 20677: 487 overlapping channels
# Hotel 5206: 487 overlapping channels
# Hotel 7097: 486 overlapping channels
# Hotel 20640: 487 overlapping channels
# Hotel 20548: 487 overlapping channels
# Hotel 11004: 487 overlapping channels
# Hotel 12480: 487 overlapping channels
# Hotel 8808: 486 overlapping channels
# Hotel 13888: 488 overlapping channels
# Hotel 20357: 488 overlapping channels
# Hotel 5797: 486 overlapping channels
# Hotel 9687: 487 overlapping channels
# Hotel 6824: 486 overlapping channels
# Hotel 18040: 486 overlapping channels
# Hotel 13050: 486 overlapping channels
# Hotel 18176: 486 overlapping channels
# Hotel 20436: 486 overlapping channels
# Hotel 11012: 486 overlapping channels
# Hotel 12307: 484 overlapping channels
# Hotel 6948: 486 overlapping channels
# Hotel 8235: 485 overlapping channels
# Hotel 11409: 487 overlapping channels
# Hotel 13429: 486 overlapping channels
# Hotel 12455: 485 overlapping channels
# Hotel 9061: 484 overlapping channels
# Hotel 14211: 485 overlapping channels
# Hotel 19568: 485 overlapping channels
# Hotel 14374: 484 overlapping channels
# Hotel 5204: 484 overlapping channels
# Hotel 2346: 486 overlapping channels
# Hotel 2669: 482 overlapping channels
# Hotel 19895: 483 overlapping channels
# Hotel 17150: 485 overlapping channels
# Hotel 20188: 486 overlapping channels
# Hotel 10708: 484 overlapping channels
# Hotel 9295: 485 overlapping channels
# Hotel 18400: 483 overlapping channels
# Hotel 8647: 484 overlapping channels
# Hotel 5203: 484 overlapping channels
# Hotel 20409: 485 overlapping channels
# Hotel 10944: 484 overlapping channels
# Hotel 15161: 487 overlapping channels
# Hotel 7353: 486 overlapping channels
# Hotel 11600: 484 overlapping channels
# Hotel 9153: 484 overlapping channels
# Hotel 6917: 486 overlapping channels
# Hotel 2534: 482 overlapping channels
# Hotel 6418: 485 overlapping channels
# Hotel 16923: 486 overlapping channels
# Hotel 15192: 486 overlapping channels
# Hotel 20122: 477 overlapping channels
# Hotel 4606: 486 overlapping channels
# Hotel 6194: 484 overlapping channels
# Hotel 19868: 486 overlapping channels
# Hotel 19865: 485 overlapping channels
# Hotel 15295: 485 overlapping channels
# Hotel 7004: 483 overlapping channels
# Hotel 13775: 481 overlapping channels
# Hotel 19653: 485 overlapping channels
# Hotel 12379: 483 overlapping channels
# Hotel 9263: 485 overlapping channels
# Hotel 20402: 485 overlapping channels
# Hotel 18641: 485 overlapping channels
# Hotel 9437: 486 overlapping channels
# Hotel 15733: 483 overlapping channels
# Hotel 8854: 483 overlapping channels
# Hotel 19913: 484 overlapping channels
# Hotel 11466: 483 overlapping channels
# Hotel 15539: 485 overlapping channels
# Hotel 11432: 484 overlapping channels
# Hotel 13659: 484 overlapping channels
# Hotel 17861: 485 overlapping channels
# Hotel 3576: 484 overlapping channels
# Hotel 8714: 481 overlapping channels
# Hotel 1101: 482 overlapping channels
# Hotel 7593: 485 overlapping channels
# Hotel 1962: 486 overlapping channels
# Hotel 4559: 483 overlapping channels
# Hotel 8637: 483 overlapping channels
# Hotel 16576: 485 overlapping channels
# Hotel 3971: 483 overlapping channels
# Hotel 20195: 483 overlapping channels
# Hotel 8842: 483 overlapping channels
# Hotel 20547: 486 overlapping channels
# Hotel 14410: 485 overlapping channels
# Hotel 300: 488 overlapping channels
# Hotel 6876: 484 overlapping channels
# Hotel 13688: 485 overlapping channels
# Hotel 5549: 482 overlapping channels
# Hotel 16677: 485 overlapping channels
# Hotel 1564: 484 overlapping channels
# Hotel 16354: 484 overlapping channels
# Hotel 13425: 484 overlapping channels
# Hotel 14356: 483 overlapping channels
# Hotel 5387: 484 overlapping channels
# Hotel 15586: 484 overlapping channels
# Hotel 19038: 485 overlapping channels
# Hotel 10870: 484 overlapping channels
# Hotel 19093: 485 overlapping channels
# Hotel 11502: 483 overlapping channels
# Hotel 16501: 483 overlapping channels
# Hotel 18170: 484 overlapping channels
# Hotel 20410: 484 overlapping channels
# Hotel 15155: 485 overlapping channels
# Hotel 14510: 483 overlapping channels
# Hotel 8517: 484 overlapping channels
# Hotel 19296: 484 overlapping channels
# Hotel 19145: 484 overlapping channels
# Hotel 18158: 483 overlapping channels
# Hotel 7318: 483 overlapping channels
# Hotel 11566: 483 overlapping channels
# Hotel 9011: 482 overlapping channels
# Hotel 17267: 482 overlapping channels
# Hotel 8766: 483 overlapping channels
# Hotel 13285: 481 overlapping channels
# Hotel 10996: 483 overlapping channels
# Hotel 17760: 484 overlapping channels
# Hotel 17735: 484 overlapping channels
# Hotel 8084: 481 overlapping channels
# Hotel 8793: 483 overlapping channels
# Hotel 10753: 482 overlapping channels
# Hotel 14739: 485 overlapping channels
# Hotel 13750: 482 overlapping channels
# Hotel 16237: 483 overlapping channels
# Hotel 16072: 484 overlapping channels
# Hotel 7644: 483 overlapping channels
# Hotel 5317: 482 overlapping channels
# Hotel 18956: 483 overlapping channels
# Hotel 6134: 483 overlapping channels
# Hotel 20447: 484 overlapping channels
# Hotel 20511: 482 overlapping channels
# Hotel 20287: 483 overlapping channels
# Hotel 4729: 483 overlapping channels
# Hotel 20482: 483 overlapping channels
# Hotel 8897: 481 overlapping channels
# Hotel 19127: 481 overlapping channels
# Hotel 8642: 480 overlapping channels
# Hotel 20318: 482 overlapping channels
# Hotel 20236: 481 overlapping channels
# Hotel 10527: 483 overlapping channels
# Hotel 3549: 481 overlapping channels
# Hotel 2299: 483 overlapping channels
# Hotel 7463: 483 overlapping channels
# Hotel 19204: 476 overlapping channels
# Hotel 13148: 479 overlapping channels
# Hotel 16830: 483 overlapping channels
# Hotel 16829: 483 overlapping channels
# Hotel 4192: 482 overlapping channels
# Hotel 20130: 484 overlapping channels
# Hotel 13362: 482 overlapping channels
# Hotel 19984: 481 overlapping channels
# Hotel 19970: 483 overlapping channels
# Hotel 7840: 483 overlapping channels
# Hotel 19953: 480 overlapping channels
# Hotel 9712: 483 overlapping channels
# Hotel 12194: 483 overlapping channels
# Hotel 8127: 481 overlapping channels
# Hotel 20674: 483 overlapping channels
# Hotel 20714: 482 overlapping channels
# Hotel 17927: 483 overlapping channels
# Hotel 14426: 481 overlapping channels
# Hotel 16533: 480 overlapping channels
# Hotel 18666: 481 overlapping channels
# Hotel 11258: 481 overlapping channels
# Hotel 18580: 481 overlapping channels
# Hotel 10725: 480 overlapping channels
# Hotel 16339: 482 overlapping channels
# Hotel 2457: 479 overlapping channels
# Hotel 11086: 481 overlapping channels
# Hotel 6853: 480 overlapping channels
# Hotel 19307: 481 overlapping channels
# Hotel 4719: 478 overlapping channels
# Hotel 14518: 481 overlapping channels
# Hotel 16734: 480 overlapping channels
# Hotel 10982: 482 overlapping channels
# Hotel 20217: 482 overlapping channels
# Hotel 20203: 482 overlapping channels
# Hotel 20499: 482 overlapping channels
# Hotel 10284: 481 overlapping channels
# Hotel 14219: 482 overlapping channels
# Hotel 2580: 477 overlapping channels
# Hotel 19319: 480 overlapping channels
# Hotel 1433: 480 overlapping channels
# Hotel 13251: 480 overlapping channels
# Hotel 4184: 481 overlapping channels
# Hotel 1949: 481 overlapping channels
# Hotel 7609: 481 overlapping channels
# Hotel 18204: 480 overlapping channels
# Hotel 14196: 481 overlapping channels
# Hotel 14831: 480 overlapping channels
# Hotel 14903: 481 overlapping channels
# Hotel 13460: 479 overlapping channels
# Hotel 13869: 477 overlapping channels
# Hotel 19182: 478 overlapping channels
# Hotel 16044: 482 overlapping channels
# Hotel 20506: 480 overlapping channels
# Hotel 18779: 478 overlapping channels
# Hotel 7215: 481 overlapping channels
# Hotel 19926: 481 overlapping channels
# Hotel 16168: 480 overlapping channels
# Hotel 20353: 481 overlapping channels
# Hotel 2618: 479 overlapping channels
# Hotel 19412: 481 overlapping channels
# Hotel 15317: 480 overlapping channels
# Hotel 14380: 481 overlapping channels
# Hotel 8592: 480 overlapping channels
# Hotel 13693: 481 overlapping channels
# Hotel 11388: 479 overlapping channels
# Hotel 9238: 480 overlapping channels
# Hotel 14497: 480 overlapping channels
# Hotel 19222: 480 overlapping channels
# Hotel 6074: 480 overlapping channels
# Hotel 16790: 481 overlapping channels
# Hotel 11181: 480 overlapping channels
# Hotel 6991: 479 overlapping channels
# Hotel 13305: 480 overlapping channels
# Hotel 1755: 480 overlapping channels
# Hotel 14453: 480 overlapping channels
# Hotel 8938: 480 overlapping channels
# Hotel 15015: 480 overlapping channels
# Hotel 17199: 480 overlapping channels
# Hotel 20588: 480 overlapping channels
# Hotel 20237: 480 overlapping channels
# Hotel 17743: 480 overlapping channels
# Hotel 3441: 478 overlapping channels
# Hotel 17121: 480 overlapping channels
# Hotel 20508: 478 overlapping channels
# Hotel 6557: 480 overlapping channels
# Hotel 7266: 479 overlapping channels
# Hotel 20649: 478 overlapping channels
# Hotel 20329: 479 overlapping channels
# Hotel 17281: 479 overlapping channels
# Hotel 13222: 479 overlapping channels
# Hotel 18792: 479 overlapping channels
# Hotel 14372: 478 overlapping channels
# Hotel 8331: 479 overlapping channels
# Hotel 20718: 479 overlapping channels
# Hotel 209: 479 overlapping channels
# Hotel 17655: 479 overlapping channels
# Hotel 10603: 479 overlapping channels
# Hotel 6575: 478 overlapping channels
# Hotel 5222: 479 overlapping channels
# Hotel 14948: 479 overlapping channels
# Hotel 14250: 479 overlapping channels
# Hotel 13823: 478 overlapping channels
# Hotel 15770: 475 overlapping channels
# Hotel 9298: 479 overlapping channels
# Hotel 16933: 479 overlapping channels
# Hotel 20183: 480 overlapping channels
# Hotel 20157: 478 overlapping channels
# Hotel 8629: 479 overlapping channels
# Hotel 19529: 479 overlapping channels
# Hotel 16915: 478 overlapping channels
# Hotel 5338: 479 overlapping channels
# Hotel 13636: 479 overlapping channels
# Hotel 11649: 479 overlapping channels
# Hotel 6940: 478 overlapping channels
# Hotel 1561: 476 overlapping channels
# Hotel 13558: 478 overlapping channels
# Hotel 20335: 477 overlapping channels
# Hotel 19700: 477 overlapping channels
# Hotel 10879: 477 overlapping channels
# Hotel 15709: 478 overlapping channels
# Hotel 9203: 478 overlapping channels
# Hotel 16252: 478 overlapping channels
# Hotel 9236: 478 overlapping channels
# Hotel 9273: 478 overlapping channels
# Hotel 17541: 478 overlapping channels
# Hotel 16180: 478 overlapping channels
# Hotel 7449: 477 overlapping channels
# Hotel 11336: 477 overlapping channels
# Hotel 12923: 477 overlapping channels
# Hotel 17252: 478 overlapping channels
# Hotel 18895: 478 overlapping channels
# Hotel 20118: 478 overlapping channels
# Hotel 20654: 478 overlapping channels
# Hotel 16540: 478 overlapping channels
# Hotel 8630: 477 overlapping channels
# Hotel 10061: 477 overlapping channels
# Hotel 14194: 478 overlapping channels
# Hotel 16169: 476 overlapping channels
# Hotel 8482: 476 overlapping channels
# Hotel 13186: 477 overlapping channels
# Hotel 14338: 477 overlapping channels
# Hotel 13924: 477 overlapping channels
# Hotel 13912: 477 overlapping channels
# Hotel 20491: 477 overlapping channels
# Hotel 5238: 477 overlapping channels
# Hotel 19756: 477 overlapping channels
# Hotel 18332: 477 overlapping channels
# Hotel 17026: 476 overlapping channels
# Hotel 19818: 477 overlapping channels
# Hotel 14323: 477 overlapping channels
# Hotel 8140: 477 overlapping channels
# Hotel 20053: 477 overlapping channels
# Hotel 18634: 477 overlapping channels
# Hotel 6075: 477 overlapping channels
# Hotel 17394: 476 overlapping channels
# Hotel 14447: 477 overlapping channels
# Hotel 11284: 477 overlapping channels
# Hotel 6523: 476 overlapping channels
# Hotel 14069: 476 overlapping channels
# Hotel 18543: 477 overlapping channels
# Hotel 10690: 477 overlapping channels
# Hotel 16609: 477 overlapping channels
# Hotel 13249: 477 overlapping channels
# Hotel 14122: 477 overlapping channels
# Hotel 19705: 475 overlapping channels
# Hotel 20300: 478 overlapping channels
# Hotel 13867: 476 overlapping channels
# Hotel 15151: 476 overlapping channels
# Hotel 15366: 476 overlapping channels
# Hotel 15427: 476 overlapping channels
# Hotel 14345: 475 overlapping channels
# Hotel 15243: 476 overlapping channels
# Hotel 19361: 476 overlapping channels
# Hotel 14390: 476 overlapping channels
# Hotel 8299: 476 overlapping channels
# Hotel 8855: 477 overlapping channels
# Hotel 15282: 476 overlapping channels
# Hotel 14829: 476 overlapping channels
# Hotel 3258: 476 overlapping channels
# Hotel 6665: 476 overlapping channels
# Hotel 17677: 476 overlapping channels
# Hotel 20374: 476 overlapping channels
# Hotel 7736: 475 overlapping channels
# Hotel 10931: 476 overlapping channels
# Hotel 3532: 476 overlapping channels
# Hotel 16554: 475 overlapping channels
# Hotel 20153: 476 overlapping channels
# Hotel 7538: 476 overlapping channels
# Hotel 18635: 476 overlapping channels
# Hotel 7511: 476 overlapping channels
# Hotel 13091: 477 overlapping channels
# Hotel 20051: 473 overlapping channels
# Hotel 17965: 476 overlapping channels
# Hotel 17758: 476 overlapping channels
# Hotel 17955: 476 overlapping channels
# Hotel 19844: 476 overlapping channels
# Hotel 2750: 476 overlapping channels
# Hotel 17827: 475 overlapping channels
# Hotel 14949: 475 overlapping channels
# Hotel 20068: 475 overlapping channels
# Hotel 6028: 475 overlapping channels
# Hotel 8441: 475 overlapping channels
# Hotel 13369: 475 overlapping channels
# Hotel 18496: 475 overlapping channels
# Hotel 18468: 473 overlapping channels
# Hotel 14306: 475 overlapping channels
# Hotel 7446: 474 overlapping channels
# Hotel 18467: 475 overlapping channels
# Hotel 15280: 475 overlapping channels
# Hotel 16708: 475 overlapping channels
# Hotel 12861: 475 overlapping channels
# Hotel 10818: 475 overlapping channels
# Hotel 17237: 475 overlapping channels
# Hotel 13824: 474 overlapping channels
# Hotel 14421: 474 overlapping channels
# Hotel 13648: 475 overlapping channels
# Hotel 20498: 475 overlapping channels
# Hotel 19491: 473 overlapping channels
# Hotel 3739: 475 overlapping channels
# Hotel 5573: 475 overlapping channels
# Hotel 17568: 475 overlapping channels
# Hotel 7149: 475 overlapping channels
# Hotel 5198: 475 overlapping channels
# Hotel 13529: 475 overlapping channels
# Hotel 1335: 474 overlapping channels
# Hotel 20419: 475 overlapping channels
# Hotel 11315: 475 overlapping channels
# Hotel 14503: 474 overlapping channels
# Hotel 6965: 474 overlapping channels
# Hotel 6711: 474 overlapping channels
# Hotel 12897: 474 overlapping channels
# Hotel 10784: 474 overlapping channels
# Hotel 18225: 474 overlapping channels
# Hotel 20507: 474 overlapping channels
# Hotel 5852: 474 overlapping channels
# Hotel 20426: 473 overlapping channels
# Hotel 14394: 474 overlapping channels
# Hotel 3397: 474 overlapping channels
# Hotel 20381: 474 overlapping channels
# Hotel 5846: 474 overlapping channels
# Hotel 13067: 474 overlapping channels
# Hotel 6605: 474 overlapping channels
# Hotel 7624: 474 overlapping channels
# Hotel 19874: 475 overlapping channels
# Hotel 15646: 475 overlapping channels
# Hotel 18501: 474 overlapping channels
# Hotel 9635: 474 overlapping channels
# Hotel 15626: 474 overlapping channels
# Hotel 9123: 473 overlapping channels
# Hotel 18910: 474 overlapping channels
# Hotel 14054: 477 overlapping channels
# Hotel 19616: 474 overlapping channels
# Hotel 19160: 473 overlapping channels
# Hotel 18803: 474 overlapping channels
# Hotel 18799: 473 overlapping channels
# Hotel 14566: 473 overlapping channels
# Hotel 8557: 473 overlapping channels
# Hotel 787: 476 overlapping channels
# Hotel 13994: 473 overlapping channels
# Hotel 7166: 473 overlapping channels
# Hotel 13652: 473 overlapping channels
# Hotel 15661: 473 overlapping channels
# Hotel 5116: 474 overlapping channels
# Hotel 19238: 473 overlapping channels
# Hotel 17523: 473 overlapping channels
# Hotel 2856: 473 overlapping channels
# Hotel 7386: 473 overlapping channels
# Hotel 12937: 472 overlapping channels
# Hotel 13433: 473 overlapping channels
# Hotel 19985: 473 overlapping channels
# Hotel 20378: 474 overlapping channels
# Hotel 13257: 473 overlapping channels
# Hotel 9471: 473 overlapping channels
# Hotel 12893: 476 overlapping channels
# Hotel 19464: 473 overlapping channels
# Hotel 18959: 472 overlapping channels
# Hotel 14251: 473 overlapping channels
# Hotel 18257: 473 overlapping channels
# Hotel 12934: 472 overlapping channels
# Hotel 13773: 472 overlapping channels
# Hotel 13747: 472 overlapping channels
# Hotel 4793: 472 overlapping channels
# Hotel 167: 473 overlapping channels
# Hotel 9219: 472 overlapping channels
# Hotel 19917: 473 overlapping channels
# Hotel 14233: 472 overlapping channels
# Hotel 13129: 472 overlapping channels
# Hotel 13531: 472 overlapping channels
# Hotel 19390: 472 overlapping channels
# Hotel 9792: 472 overlapping channels
# Hotel 9180: 472 overlapping channels
# Hotel 20415: 472 overlapping channels
# Hotel 19262: 472 overlapping channels
# Hotel 17280: 472 overlapping channels
# Hotel 15207: 472 overlapping channels
# Hotel 7357: 472 overlapping channels
# Hotel 7680: 472 overlapping channels
# Hotel 18317: 473 overlapping channels
# Hotel 18685: 472 overlapping channels
# Hotel 19067: 472 overlapping channels
# Hotel 7259: 472 overlapping channels
# Hotel 7648: 472 overlapping channels
# Hotel 1614: 474 overlapping channels
# Hotel 16539: 472 overlapping channels
# Hotel 17579: 472 overlapping channels
# Hotel 8980: 471 overlapping channels
# Hotel 8569: 471 overlapping channels
# Hotel 13439: 471 overlapping channels
# Hotel 18875: 471 overlapping channels
# Hotel 18994: 471 overlapping channels
# Hotel 7748: 471 overlapping channels
# Hotel 14968: 470 overlapping channels
# Hotel 10348: 471 overlapping channels
# Hotel 9135: 471 overlapping channels
# Hotel 7271: 471 overlapping channels
# Hotel 567: 471 overlapping channels
# Hotel 13370: 471 overlapping channels
# Hotel 14258: 471 overlapping channels
# Hotel 15186: 471 overlapping channels
# Hotel 16854: 471 overlapping channels
# Hotel 13178: 472 overlapping channels
# Hotel 18411: 471 overlapping channels
# Hotel 18276: 471 overlapping channels
# Hotel 14502: 471 overlapping channels
# Hotel 10008: 471 overlapping channels
# Hotel 7909: 471 overlapping channels
# Hotel 19233: 471 overlapping channels
# Hotel 15673: 471 overlapping channels
# Hotel 19358: 472 overlapping channels
# Hotel 8792: 471 overlapping channels
# Hotel 8790: 471 overlapping channels
# Hotel 15714: 471 overlapping channels
# Hotel 13981: 471 overlapping channels
# Hotel 17964: 471 overlapping channels
# Hotel 19802: 472 overlapping channels
# Hotel 8093: 471 overlapping channels
# Hotel 3188: 471 overlapping channels
# Hotel 18638: 471 overlapping channels
# Hotel 8325: 471 overlapping channels
# Hotel 8912: 471 overlapping channels
# Hotel 7971: 471 overlapping channels
# Hotel 14782: 471 overlapping channels
# Hotel 19944: 471 overlapping channels
# Hotel 13317: 471 overlapping channels
# Hotel 19807: 469 overlapping channels
# Hotel 19876: 470 overlapping channels
# Hotel 5164: 470 overlapping channels
# Hotel 14170: 470 overlapping channels
# Hotel 19893: 472 overlapping channels
# Hotel 16315: 471 overlapping channels
# Hotel 13353: 470 overlapping channels
# Hotel 17863: 470 overlapping channels
# Hotel 13294: 470 overlapping channels
# Hotel 2484: 470 overlapping channels
# Hotel 3250: 470 overlapping channels
# Hotel 11360: 470 overlapping channels
# Hotel 3299: 470 overlapping channels
# Hotel 20558: 469 overlapping channels
# Hotel 7151: 473 overlapping channels
# Hotel 16698: 470 overlapping channels
# Hotel 3153: 470 overlapping channels
# Hotel 2654: 471 overlapping channels
# Hotel 7309: 470 overlapping channels
# Hotel 10302: 469 overlapping channels
# Hotel 10677: 470 overlapping channels
# Hotel 17069: 470 overlapping channels
# Hotel 7811: 469 overlapping channels
# Hotel 11002: 469 overlapping channels
# Hotel 20161: 469 overlapping channels
# Hotel 3289: 469 overlapping channels
# Hotel 17750: 469 overlapping channels
# Hotel 13826: 469 overlapping channels
# Hotel 17218: 469 overlapping channels
# Hotel 16377: 469 overlapping channels
# Hotel 7156: 469 overlapping channels
# Hotel 20325: 470 overlapping channels
# Hotel 17615: 469 overlapping channels
# Hotel 16024: 469 overlapping channels
# Hotel 17999: 469 overlapping channels
# Hotel 12303: 469 overlapping channels
# Hotel 20239: 469 overlapping channels
# Hotel 17428: 469 overlapping channels
# Hotel 10882: 469 overlapping channels
# Hotel 7912: 469 overlapping channels
# Hotel 8794: 469 overlapping channels
# Hotel 18998: 469 overlapping channels
# Hotel 19207: 467 overlapping channels
# Hotel 1064: 469 overlapping channels
# Hotel 8892: 469 overlapping channels
# Hotel 15562: 470 overlapping channels
# Hotel 14174: 469 overlapping channels
# Hotel 14601: 467 overlapping channels
# Hotel 14432: 469 overlapping channels
# Hotel 19107: 469 overlapping channels
# Hotel 15170: 470 overlapping channels
# Hotel 13431: 468 overlapping channels
# Hotel 7074: 468 overlapping channels
# Hotel 8046: 469 overlapping channels
# Hotel 15985: 468 overlapping channels
# Hotel 14080: 469 overlapping channels
# Hotel 8965: 468 overlapping channels
# Hotel 6488: 468 overlapping channels
# Hotel 15461: 468 overlapping channels
# Hotel 18551: 468 overlapping channels
# Hotel 7954: 468 overlapping channels
# Hotel 17755: 469 overlapping channels
# Hotel 19887: 469 overlapping channels
# Hotel 2487: 468 overlapping channels
# Hotel 19607: 468 overlapping channels
# Hotel 15442: 468 overlapping channels
# Hotel 20180: 468 overlapping channels
# Hotel 10662: 468 overlapping channels
# Hotel 18675: 469 overlapping channels
# Hotel 15600: 468 overlapping channels
# Hotel 15636: 468 overlapping channels
# Hotel 11130: 468 overlapping channels
# Hotel 17811: 468 overlapping channels
# Hotel 8534: 470 overlapping channels
# Hotel 20159: 468 overlapping channels
# Hotel 19166: 468 overlapping channels
# Hotel 15210: 468 overlapping channels
# Hotel 14272: 467 overlapping channels
# Hotel 8547: 467 overlapping channels
# Hotel 9723: 467 overlapping channels
# Hotel 16871: 468 overlapping channels
# Hotel 18356: 466 overlapping channels
# Hotel 20146: 467 overlapping channels
# Hotel 13321: 467 overlapping channels
# Hotel 13112: 467 overlapping channels
# Hotel 14933: 467 overlapping channels
# Hotel 17248: 467 overlapping channels
# Hotel 17580: 468 overlapping channels
# Hotel 2995: 467 overlapping channels
# Hotel 10763: 467 overlapping channels
# Hotel 16686: 467 overlapping channels
# Hotel 4465: 467 overlapping channels
# Hotel 13145: 467 overlapping channels
# Hotel 14096: 467 overlapping channels
# Hotel 15873: 467 overlapping channels
# Hotel 17633: 467 overlapping channels
# Hotel 6206: 467 overlapping channels
# Hotel 11051: 468 overlapping channels
# Hotel 15258: 466 overlapping channels
# Hotel 18026: 467 overlapping channels
# Hotel 20070: 467 overlapping channels
# Hotel 8479: 466 overlapping channels
# Hotel 14195: 466 overlapping channels
# Hotel 7106: 466 overlapping channels
# Hotel 16593: 466 overlapping channels
# Hotel 6497: 466 overlapping channels
# Hotel 15936: 467 overlapping channels
# Hotel 16216: 468 overlapping channels
# Hotel 14620: 468 overlapping channels
# Hotel 10214: 466 overlapping channels
# Hotel 16751: 466 overlapping channels
# Hotel 12520: 466 overlapping channels
# Hotel 5158: 466 overlapping channels
# Hotel 17257: 466 overlapping channels
# Hotel 9325: 466 overlapping channels
# Hotel 13855: 467 overlapping channels
# Hotel 6285: 466 overlapping channels
# Hotel 7400: 468 overlapping channels
# Hotel 10872: 466 overlapping channels
# Hotel 16551: 466 overlapping channels
# Hotel 4214: 466 overlapping channels
# Hotel 14728: 466 overlapping channels
# Hotel 17587: 466 overlapping channels
# Hotel 7195: 466 overlapping channels
# Hotel 19684: 466 overlapping channels
# Hotel 18270: 466 overlapping channels
# Hotel 14098: 466 overlapping channels
# Hotel 996: 466 overlapping channels
# Hotel 13544: 466 overlapping channels
# Hotel 14346: 466 overlapping channels
# Hotel 9669: 466 overlapping channels
# Hotel 15342: 467 overlapping channels
# Hotel 20057: 466 overlapping channels
# Hotel 20488: 465 overlapping channels
# Hotel 5279: 466 overlapping channels
# Hotel 13979: 465 overlapping channels
# Hotel 6807: 465 overlapping channels
# Hotel 3999: 465 overlapping channels
# Hotel 16245: 470 overlapping channels
# Hotel 8147: 465 overlapping channels
# Hotel 7342: 465 overlapping channels
# Hotel 3259: 465 overlapping channels
# Hotel 7552: 466 overlapping channels
# Hotel 17786: 465 overlapping channels
# Hotel 18091: 465 overlapping channels
# Hotel 8162: 466 overlapping channels
# Hotel 15832: 465 overlapping channels
# Hotel 1905: 465 overlapping channels
# Hotel 13434: 465 overlapping channels
# Hotel 1726: 465 overlapping channels
# Hotel 13402: 465 overlapping channels
# Hotel 3925: 466 overlapping channels
# Hotel 8440: 465 overlapping channels
# Hotel 10365: 465 overlapping channels
# Hotel 9221: 465 overlapping channels
# Hotel 17854: 465 overlapping channels
# Hotel 17911: 464 overlapping channels
# Hotel 20205: 465 overlapping channels
# Hotel 7363: 464 overlapping channels
# Hotel 17422: 464 overlapping channels
# Hotel 17845: 464 overlapping channels
# Hotel 14396: 465 overlapping channels
# Hotel 14411: 464 overlapping channels
# Hotel 17545: 465 overlapping channels
# Hotel 19388: 464 overlapping channels
# Hotel 7193: 464 overlapping channels
# Hotel 8954: 465 overlapping channels
# Hotel 8711: 464 overlapping channels
# Hotel 7265: 464 overlapping channels
# Hotel 17389: 464 overlapping channels
# Hotel 12237: 464 overlapping channels
# Hotel 16365: 465 overlapping channels
# Hotel 15291: 464 overlapping channels
# Hotel 2167: 464 overlapping channels
# Hotel 19823: 464 overlapping channels
# Hotel 14052: 468 overlapping channels
# Hotel 4823: 464 overlapping channels
# Hotel 20141: 464 overlapping channels
# Hotel 3603: 464 overlapping channels
# Hotel 1976: 464 overlapping channels
# Hotel 14139: 464 overlapping channels
# Hotel 8059: 464 overlapping channels
# Hotel 5059: 464 overlapping channels
# Hotel 18369: 464 overlapping channels
# Hotel 13804: 464 overlapping channels
# Hotel 9566: 464 overlapping channels
# Hotel 13051: 464 overlapping channels
# Hotel 2512: 464 overlapping channels
# Hotel 20541: 465 overlapping channels
# Hotel 8018: 463 overlapping channels
# Hotel 12875: 463 overlapping channels
# Hotel 8016: 463 overlapping channels
# Hotel 19688: 464 overlapping channels
# Hotel 16466: 464 overlapping channels
# Hotel 18593: 463 overlapping channels
# Hotel 18498: 465 overlapping channels
# Hotel 5094: 463 overlapping channels
# Hotel 3767: 463 overlapping channels
# Hotel 16089: 463 overlapping channels
# Hotel 14615: 465 overlapping channels
# Hotel 13449: 463 overlapping channels
# Hotel 20075: 464 overlapping channels
# Hotel 5902: 463 overlapping channels
# Hotel 14289: 463 overlapping channels
# Hotel 17001: 465 overlapping channels
# Hotel 6771: 463 overlapping channels
# Hotel 17233: 463 overlapping channels
# Hotel 10578: 463 overlapping channels
# Hotel 18693: 463 overlapping channels
# Hotel 20167: 463 overlapping channels
# Hotel 13838: 464 overlapping channels
# Hotel 19535: 463 overlapping channels
# Hotel 8532: 463 overlapping channels
# Hotel 3771: 462 overlapping channels
# Hotel 1256: 462 overlapping channels
# Hotel 11041: 462 overlapping channels
# Hotel 7064: 462 overlapping channels
# Hotel 17971: 462 overlapping channels
# Hotel 19736: 462 overlapping channels
# Hotel 2627: 463 overlapping channels
# Hotel 14050: 467 overlapping channels
# Hotel 17789: 462 overlapping channels
# Hotel 16117: 462 overlapping channels
# Hotel 19724: 463 overlapping channels
# Hotel 2101: 462 overlapping channels
# Hotel 3558: 462 overlapping channels
# Hotel 7183: 462 overlapping channels
# Hotel 19082: 462 overlapping channels
# Hotel 17057: 462 overlapping channels
# Hotel 10554: 463 overlapping channels
# Hotel 5056: 463 overlapping channels
# Hotel 6594: 462 overlapping channels
# Hotel 13332: 462 overlapping channels
# Hotel 9716: 462 overlapping channels
# Hotel 15335: 462 overlapping channels
# Hotel 17425: 462 overlapping channels
# Hotel 19975: 463 overlapping channels
# Hotel 8473: 462 overlapping channels
# Hotel 2091: 462 overlapping channels
# Hotel 18020: 463 overlapping channels
# Hotel 17504: 463 overlapping channels
# Hotel 6887: 462 overlapping channels
# Hotel 13505: 462 overlapping channels
# Hotel 7896: 462 overlapping channels
# Hotel 18021: 462 overlapping channels
# Hotel 8661: 461 overlapping channels
# Hotel 9383: 462 overlapping channels
# Hotel 6056: 461 overlapping channels
# Hotel 10720: 461 overlapping channels
# Hotel 4566: 462 overlapping channels
# Hotel 9393: 461 overlapping channels
# Hotel 6081: 462 overlapping channels
# Hotel 10761: 461 overlapping channels
# Hotel 5455: 462 overlapping channels
# Hotel 4132: 461 overlapping channels
# Hotel 7268: 461 overlapping channels
# Hotel 4543: 461 overlapping channels
# Hotel 8243: 462 overlapping channels
# Hotel 13724: 461 overlapping channels
# Hotel 15935: 462 overlapping channels
# Hotel 11467: 461 overlapping channels
# Hotel 12663: 463 overlapping channels
# Hotel 18462: 462 overlapping channels
# Hotel 16835: 462 overlapping channels
# Hotel 16766: 461 overlapping channels
# Hotel 19880: 461 overlapping channels
# Hotel 18874: 462 overlapping channels
# Hotel 17620: 463 overlapping channels
# Hotel 16357: 461 overlapping channels
# Hotel 20412: 462 overlapping channels
# Hotel 18301: 461 overlapping channels
# Hotel 19377: 461 overlapping channels
# Hotel 16209: 462 overlapping channels
# Hotel 17729: 461 overlapping channels
# Hotel 17985: 461 overlapping channels
# Hotel 18102: 461 overlapping channels
# Hotel 18726: 462 overlapping channels
# Hotel 18253: 461 overlapping channels
# Hotel 13927: 461 overlapping channels
# Hotel 17998: 461 overlapping channels
# Hotel 14056: 461 overlapping channels
# Hotel 2137: 464 overlapping channels
# Hotel 15611: 460 overlapping channels
# Hotel 10793: 460 overlapping channels
# Hotel 18264: 460 overlapping channels
# Hotel 4989: 460 overlapping channels
# Hotel 19429: 461 overlapping channels
# Hotel 19847: 465 overlapping channels
# Hotel 12454: 460 overlapping channels
# Hotel 12551: 461 overlapping channels
# Hotel 17276: 463 overlapping channels
# Hotel 8478: 460 overlapping channels
# Hotel 8533: 461 overlapping channels
# Hotel 10249: 460 overlapping channels
# Hotel 3646: 462 overlapping channels
# Hotel 13347: 461 overlapping channels
# Hotel 9007: 460 overlapping channels
# Hotel 3401: 460 overlapping channels
# Hotel 10311: 460 overlapping channels
# Hotel 12831: 460 overlapping channels
# Hotel 18383: 460 overlapping channels
# Hotel 9647: 460 overlapping channels

# %%
existing_pairs = set(zip(hotel_city_chanel_combin_extract['Hotel_ID'], 
                         hotel_city_chanel_combin_extract['Canal_ID']))

# %%
# Define a helper function
def is_existing_channel(row):
    return (row['hotel_id'], row['channel_id']) in existing_pairs

# Filter out existing pairs
filtered_long_scores_df = long_scores_df[~long_scores_df.apply(is_existing_channel, axis=1)].copy()

# %%
# Step 1a: Create a matrix of shape (n_hotels, n_channels) from long_scores_df
# Pivot so rows = hotel, cols = channel, values = score
channel_rec_matrix = long_scores_df.pivot(index='hotel_id', columns='channel_id', values='score').fillna(0)

# Step 1b: Compute pairwise cosine similarity between hotels based on channel rec scores
channel_similarity_matrix = cosine_similarity(channel_rec_matrix)

# %%
# If hotel_similarity_df is a DataFrame, convert it to numpy array aligned with channel_rec_matrix rows
hotel_ids = channel_rec_matrix.index
hotel_similarity_matrix = similarity_df.loc[hotel_ids, hotel_ids].values

# %%
# Step 1c: Flatten the upper triangles of both similarity matrices
def flatten_upper_tri(matrix):
    triu_indices = np.triu_indices_from(matrix, k=1)
    return matrix[triu_indices]

hotel_sim_flat = flatten_upper_tri(hotel_similarity_matrix)
channel_sim_flat = flatten_upper_tri(channel_similarity_matrix)

# Step 1d: Compute correlation between hotel similarity and channel recommendation similarity
corr, pval = spearmanr(hotel_sim_flat, channel_sim_flat)
print(f"Spearman correlation between hotel similarity and channel rec similarity: {corr:.4f} (p-value={pval:.4g})")
# Out:
# Spearman correlation between hotel similarity and channel rec similarity: -0.2300 (p-value=0)

# %%
from sklearn.metrics import jaccard_score

top_n = 100

# Step 2a: For each hotel, get the top N recommended channels
top_channels_per_hotel = (
    long_scores_df
    .groupby('hotel_id')
    .apply(lambda df: set(df.nlargest(top_n, 'score')['channel_id']))
)

# Step 2b: Create a binary matrix (hotel x channel), 1 if channel in top-N, else 0
all_channels = sorted(long_scores_df['channel_id'].unique())
hotel_ids = sorted(long_scores_df['hotel_id'].unique())

binary_matrix = pd.DataFrame(0, index=hotel_ids, columns=all_channels, dtype=int)

for hotel_id, channels in top_channels_per_hotel.items():
    binary_matrix.loc[hotel_id, list(channels)] = 1

# Step 2c: Compute pairwise Jaccard similarity between hotels
def pairwise_jaccard(matrix):
    n = matrix.shape[0]
    result = np.zeros((n, n))
    for i in range(n):
        for j in range(i+1, n):
            result[i, j] = jaccard_score(matrix.iloc[i], matrix.iloc[j])
            result[j, i] = result[i, j]
    return result

jaccard_similarity_matrix = pairwise_jaccard(binary_matrix)

# Step 2d: Flatten matrices as before
hotel_sim_flat = flatten_upper_tri(hotel_similarity_matrix)
jaccard_sim_flat = flatten_upper_tri(jaccard_similarity_matrix)

# Step 2e: Correlate hotel similarity and Jaccard similarity of top-N channels
corr_jaccard, pval_jaccard = spearmanr(hotel_sim_flat, jaccard_sim_flat)
print(f"Spearman correlation between hotel similarity and top-{top_n} channel Jaccard similarity: {corr_jaccard:.4f} (p-value={pval_jaccard:.4g})")
# Out:
# C:\Users\paulo\AppData\Local\Temp\ipykernel_12604\1383318987.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: set(df.nlargest(top_n, 'score')['channel_id']))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 31
#      28             result[j, i] = result[i, j]
#      29     return result
# ---> 31 jaccard_similarity_matrix = pairwise_jaccard(binary_matrix)
#      33 # Step 2d: Flatten matrices as before
#      34 hotel_sim_flat = flatten_upper_tri(hotel_similarity_matrix)
#
# Cell In[67], line 27, in pairwise_jaccard(matrix)
#      25 for i in range(n):
#      26     for j in range(i+1, n):
# ---> 27         result[i, j] = jaccard_score(matrix.iloc[i], matrix.iloc[j])
#      28         result[j, i] = result[i, j]
#      29 return result
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\metrics\_classification.py:925, in jaccard_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     923 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#     924 samplewise = average == "samples"
# --> 925 MCM = multilabel_confusion_matrix(
#     926     y_true,
#     927     y_pred,
#     928     sample_weight=sample_weight,
#     929     labels=labels,
#     930     samplewise=samplewise,
#     931 )
#     932 numerator = MCM[:, 1, 1]
#     933 denominator = MCM[:, 1, 1] + MCM[:, 0, 1] + MCM[:, 1, 0]
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\metrics\_classification.py:562, in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     560 le.fit(labels)
#     561 y_true = le.transform(y_true)
# --> 562 y_pred = le.transform(y_pred)
#     563 sorted_labels = le.classes_
#     565 # labels are now from 0 to len(labels) - 1 -> use bincount
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\preprocessing\_label.py:134, in LabelEncoder.transform(self, y)
#     131 if _num_samples(y) == 0:
#     132     return xp.asarray([])
# --> 134 return _encode(y, uniques=self.classes_)
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\utils\_encode.py:243, in _encode(values, uniques, check_unknown)
#     241     if diff:
#     242         raise ValueError(f"y contains previously unseen labels: {str(diff)}")
# --> 243 return _searchsorted(uniques, values, xp=xp)
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\sklearn\utils\_array_api.py:944, in _searchsorted(a, v, side, sorter, xp)
#     942 xp, _ = get_namespace(a, v, xp=xp)
#     943 if hasattr(xp, "searchsorted"):
# --> 944     return xp.searchsorted(a, v, side=side, sorter=sorter)
#     946 a_np = _convert_to_numpy(a, xp=xp)
#     947 v_np = _convert_to_numpy(v, xp=xp)
#
# File <__array_function__ internals>:180, in searchsorted(*args, **kwargs)
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\numpy\core\fromnumeric.py:1387, in searchsorted(a, v, side, sorter)
#    1319 @array_function_dispatch(_searchsorted_dispatcher)
#    1320 def searchsorted(a, v, side='left', sorter=None):
#    1321     """
#    1322     Find indices where elements should be inserted to maintain order.
#    1323
#    (...)
#    1385
#    1386     """
# -> 1387     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File c:\Users\paulo\Desktop\2a - SVD Missing Channels to Hotels - Copy\myenv\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# Step 3a: Cluster hotels by latent vectors (use hotel_similarity_df as proxy)

# Convert similarity to distance
hotel_distance = 1 - hotel_similarity_matrix

# Use MDS or PCA to embed distance matrix into Euclidean space (optional, here use directly)
# For simplicity, use spectral embedding or PCA here (optional)

# Or cluster directly on the latent vectors if available (you might have them in model)

# Let's assume you have latent vectors in a DataFrame hotel_latent_vectors:
# hotel_latent_vectors = pd.DataFrame(..., index=hotel_ids)

# Example: cluster by hotel latent vectors (if available)
# km_latent = KMeans(n_clusters=10, random_state=42).fit_predict(hotel_latent_vectors)

# If not available, cluster by hotel similarity matrix using spectral clustering:
from sklearn.cluster import SpectralClustering

n_clusters = 10
spectral = SpectralClustering(n_clusters=n_clusters, affinity='precomputed', random_state=42)
clusters_hotels = spectral.fit_predict(hotel_similarity_matrix)

# Step 3b: Cluster hotels by their channel recommendations (use channel similarity matrix)
km_channel = KMeans(n_clusters=n_clusters, random_state=42).fit_predict(channel_rec_matrix)

# Step 3c: Compute Adjusted Rand Index between clusters
ari = adjusted_rand_score(clusters_hotels, km_channel)
print(f"Adjusted Rand Index between hotel clusters and channel recommendation clusters: {ari:.4f}")
